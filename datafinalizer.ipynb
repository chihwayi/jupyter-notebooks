# %%
import pandas as pd

# %%
data = pd.read_csv('/home/ignatious/Documents/tb screening/Harare.csv')
# Out:
# /home/ignatious/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#                PatientID DateOfBirth     Sex   VisitDate VisitTypeCode  \
# 0  00-0A-05-2012-A-02649  18/04/1991  Female  04/05/2015             P
# 1  00-0A-05-2016-A-00048  01/02/1986    Male  22/06/2016             P
# 2  00-0A-0D-2004-A-00115  04/05/1977  Female  05/04/2019            TS
# 3  00-0A-0D-2007-A-06438  28/12/1958  Female  25/08/2017             P
# 4  00-0A-0D-2009-A-00183  04/07/1969  Female  21/06/2019            TS
#
#   TBStatusDescription ARVStatusDescription Facilitycode Districtcode  \
# 0        Not assessed         Continue ARV           14            F
# 1        Not assessed               No ARV           14            F
# 2        Not assessed         Continue ARV           14            F
# 3        Not assessed         Continue ARV           14            F
# 4        Not assessed         Continue ARV           14            F
#
#    Provincedoce        FacilityName             District Province
# ...

# %%
data['Date'] = pd.to_datetime(data['VisitDate'],errors='coerce')

# %%
data['Period'] = pd.DatetimeIndex(data['Date']).month

# %%
data.head()
# Out:
#                PatientID DateOfBirth     Sex   VisitDate VisitTypeCode  \
# 0  00-0A-05-2012-A-02649  18/04/1991  Female  04/05/2015             P
# 1  00-0A-05-2016-A-00048  01/02/1986    Male  22/06/2016             P
# 2  00-0A-0D-2004-A-00115  04/05/1977  Female  05/04/2019            TS
# 3  00-0A-0D-2007-A-06438  28/12/1958  Female  25/08/2017             P
# 4  00-0A-0D-2009-A-00183  04/07/1969  Female  21/06/2019            TS
#
#   TBStatusDescription ARVStatusDescription Facilitycode Districtcode  \
# 0        Not assessed         Continue ARV           14            F
# 1        Not assessed               No ARV           14            F
# 2        Not assessed         Continue ARV           14            F
# 3        Not assessed         Continue ARV           14            F
# 4        Not assessed         Continue ARV           14            F
#
#    Provincedoce        FacilityName             District Province       Date  \
# ...

# %%
del data['Date']

# %%
data.head()
# Out:
#                PatientID DateOfBirth     Sex   VisitDate VisitTypeCode  \
# 0  00-0A-05-2012-A-02649  18/04/1991  Female  04/05/2015             P
# 1  00-0A-05-2016-A-00048  01/02/1986    Male  22/06/2016             P
# 2  00-0A-0D-2004-A-00115  04/05/1977  Female  05/04/2019            TS
# 3  00-0A-0D-2007-A-06438  28/12/1958  Female  25/08/2017             P
# 4  00-0A-0D-2009-A-00183  04/07/1969  Female  21/06/2019            TS
#
#   TBStatusDescription ARVStatusDescription Facilitycode Districtcode  \
# 0        Not assessed         Continue ARV           14            F
# 1        Not assessed               No ARV           14            F
# 2        Not assessed         Continue ARV           14            F
# 3        Not assessed         Continue ARV           14            F
# 4        Not assessed         Continue ARV           14            F
#
#    Provincedoce        FacilityName             District Province  Period
# ...

# %%
data = data[['PatientID','DateOfBirth','Sex','VisitDate','Period','VisitTypeCode','TBStatusDescription','ARVStatusDescription','Facilitycode','Districtcode','Provincedoce','FacilityName','District','Province']]

# %%
data.head()
# Out:
#                PatientID DateOfBirth     Sex   VisitDate  Period  \
# 0  00-0A-05-2012-A-02649  18/04/1991  Female  04/05/2015     4.0
# 1  00-0A-05-2016-A-00048  01/02/1986    Male  22/06/2016     6.0
# 2  00-0A-0D-2004-A-00115  04/05/1977  Female  05/04/2019     5.0
# 3  00-0A-0D-2007-A-06438  28/12/1958  Female  25/08/2017     8.0
# 4  00-0A-0D-2009-A-00183  04/07/1969  Female  21/06/2019     6.0
#
#   VisitTypeCode TBStatusDescription ARVStatusDescription Facilitycode  \
# 0             P        Not assessed         Continue ARV           14
# 1             P        Not assessed               No ARV           14
# 2            TS        Not assessed         Continue ARV           14
# 3             P        Not assessed         Continue ARV           14
# 4            TS        Not assessed         Continue ARV           14
#
#   Districtcode  Provincedoce        FacilityName             District Province
# ...

# %%
data.to_csv('/home/ignatious/Documents/tb screening/Harare data.csv')
