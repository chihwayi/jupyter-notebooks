# %%
import pandas as pd

# %%
a = pd.read_csv("fulldata.csv")
b = pd.read_csv("AllScreened.csv")

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 6 columns):
# FacilityName    390 non-null object
# Current..       390 non-null int64
# No sign..       390 non-null object
# Not ass..       390 non-null object
# Suspect..       390 non-null int64
# Total           390 non-null object
# dtypes: int64(2), object(4)
# memory usage: 18.4+ KB

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 3 columns):
# FacilityName    384 non-null object
# District        385 non-null object
# Province        385 non-null object
# dtypes: object(3)
# memory usage: 9.1+ KB

# %%
result = a.loc[~a['FacilityName'].isin(b['FacilityName'])]

# %%
result
# Out:
#                  FacilityName  Current.. No sign.. Not ass..  Suspect..  \
# 2              Amaveni Clinic          2        41         8          0
# 4        Avoca Rural Hospital          4         2         0          0
# 10      Berejena Mission Ho..          0         3         0          0
# 23      Budiriro Satellite ..          0     2,983         0          0
# 37      Chikuku Rural Hospi..          9     2,828        22          3
# 38      Chikwingwizha Hospi..          2       318         7          0
# 44      Chinhoyi Provincial..          0        41         2          0
# 50   Chireya Mission Hospital          1     1,034        10          1
# 56              Chitse Clinic          0        14         6          0
# 58      Chitsungo Mission H..          0         2         0          0
# 60      Chivi District Hosp..          5       774        17          0
# 83      Emakhandeni Day Cli..         33     6,915       869          2
# ...

# %%
merged = a.merge(b, on='FacilityName')

# %%
result.to_csv("mbito2.csv", index=False)

# %%
a['FacilityName'] =! b['FacilityName']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-cb4c776dd4cb> in <module>
# ----> 1 a['FacilityName'] =get_ipython().getoutput(" b['FacilityName']")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
#    3446         NDFrame._set_item(self, key, value)
#    3447
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3628
#    3629             # turn me into an ndarray
# ...

# %%
merged.to_csv("mbito.csv", index=False)
